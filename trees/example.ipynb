# %%
# Example that just runs the main script. See that code for more model details, but it's pretty simple.
import numpy as np
from main import main

main(max_depth=6)
# Out:
# Dataset: make_moons. Training accuracy: 99.00
# Dataset: make_circles. Training accuracy: 100.00
# Dataset: make_blobs. Training accuracy: 100.00
